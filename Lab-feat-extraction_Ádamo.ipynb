# %%
# !pip install numpy

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
customer_df = pd.read_csv('we_fn_use_c_marketing_customer_value_analysis.csv')
customer_df
# Out:
#      Customer       State  Customer Lifetime Value Response  Coverage  \
# 0     BU79786  Washington              2763.519279       No     Basic
# 1     QZ44356     Arizona              6979.535903       No  Extended
# 2     AI49188      Nevada             12887.431650       No   Premium
# 3     WW63253  California              7645.861827       No     Basic
# 4     HB64268  Washington              2813.692575       No     Basic
# ...       ...         ...                      ...      ...       ...
# 9129  LA72316  California             23405.987980       No     Basic
# 9130  PK87824  California              3096.511217      Yes  Extended
# 9131  TD14365  California              8163.890428       No  Extended
# 9132  UP19263  California              7524.442436       No  Extended
# 9133  Y167826  California              2611.836866       No  Extended
#
#      Education Effective To Date EmploymentStatus Gender  Income  ...  \
# ...

# %%
customer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9134 entries, 0 to 9133
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Customer                       9134 non-null   object
#  1   State                          9134 non-null   object
#  2   Customer Lifetime Value        9134 non-null   float64
#  3   Response                       9134 non-null   object
#  4   Coverage                       9134 non-null   object
#  5   Education                      9134 non-null   object
#  6   Effective To Date              9134 non-null   object
#  7   EmploymentStatus               9134 non-null   object
#  8   Gender                         9134 non-null   object
#  9   Income                         9134 non-null   int64
#  10  Location Code                  9134 non-null   object
#  11  Marital Status                 9134 non-null   object
# ...

# %%
customer_df.shape
# Out:
# (9134, 24)

# %%
customer_df.head()
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income  ...  \
# 0           2/24/11         Employed      F   56274  ...
# 1           1/31/11       Unemployed      F       0  ...
# 2           2/19/11         Employed      F   48767  ...
# 3           1/20/11       Unemployed      M       0  ...
# 4            2/3/11         Employed      M   43836  ...
#
#   Months Since Policy Inception Number of Open Complaints  Number of Policies  \
# ...

# %%
customer_df.columns = customer_df.columns.str.lower()

# %%
customer_df.columns = customer_df.columns.str.replace(' ', '_')

# %%
customer_df.columns
# Out:
# Index(['customer', 'state', 'customer_lifetime_value', 'response', 'coverage',
#        'education', 'effective_to_date', 'employmentstatus', 'gender',
#        'income', 'location_code', 'marital_status', 'monthly_premium_auto',
#        'months_since_last_claim', 'months_since_policy_inception',
#        'number_of_open_complaints', 'number_of_policies', 'policy_type',
#        'policy', 'renew_offer_type', 'sales_channel', 'total_claim_amount',
#        'vehicle_class', 'vehicle_size'],
#       dtype='object')

# %%
customer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9134 entries, 0 to 9133
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   customer                       9134 non-null   object
#  1   state                          9134 non-null   object
#  2   customer_lifetime_value        9134 non-null   float64
#  3   response                       9134 non-null   object
#  4   coverage                       9134 non-null   object
#  5   education                      9134 non-null   object
#  6   effective_to_date              9134 non-null   object
#  7   employmentstatus               9134 non-null   object
#  8   gender                         9134 non-null   object
#  9   income                         9134 non-null   int64
#  10  location_code                  9134 non-null   object
#  11  marital_status                 9134 non-null   object
# ...

# %%
from datetime import datetime
customer_df['effective_to_date'] = pd.to_datetime(customer_df['effective_to_date'])
customer_df.effective_to_date
# Out:
# C:\Users\Ádamo\AppData\Local\Temp\ipykernel_6964\3619272021.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   customer_df['effective_to_date'] = pd.to_datetime(customer_df['effective_to_date'])
# 0      2011-02-24
# 1      2011-01-31
# 2      2011-02-19
# 3      2011-01-20
# 4      2011-02-03
#           ...
# 9129   2011-02-10
# 9130   2011-02-12
# 9131   2011-02-06
# 9132   2011-02-03
# 9133   2011-02-14
# Name: effective_to_date, Length: 9134, dtype: datetime64[ns]

# %%
numerical = customer_df[['customer_lifetime_value', 'income', 'monthly_premium_auto', 'months_since_last_claim', 'months_since_policy_inception', 'number_of_open_complaints', 'number_of_policies', 'total_claim_amount']]
categorical = customer_df[['state', 'response', 'coverage', 'education', 'effective_to_date', 'employmentstatus', 'gender', 'location_code', 'marital_status', 'policy_type', 'policy', 'renew_offer_type', 'sales_channel', 'vehicle_class', 'vehicle_size']]

# %%
numerical.corr()
# Out:
#                                customer_lifetime_value    income  \
# customer_lifetime_value                       1.000000  0.024366
# income                                        0.024366  1.000000
# monthly_premium_auto                          0.396262 -0.016665
# months_since_last_claim                       0.011517 -0.026715
# months_since_policy_inception                 0.009418 -0.000875
# number_of_open_complaints                    -0.036343  0.006408
# number_of_policies                            0.021955 -0.008656
# total_claim_amount                            0.226451 -0.355254
#
#                                monthly_premium_auto  months_since_last_claim  \
# customer_lifetime_value                    0.396262                 0.011517
# income                                    -0.016665                -0.026715
# monthly_premium_auto                       1.000000                 0.005026
# ...

# %%
sns.set(style="whitegrid")
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728']
fig, axes = plt.subplots(2, 2, figsize=(12, 8))
columns = ['customer_lifetime_value', 'income', 'monthly_premium_auto', 'total_claim_amount']

for i, col in enumerate(columns):
    sns.kdeplot(customer_df[col], shade=True, color=colors[i], ax=axes[i//2, i%2])
    axes[i//2, i%2].set_xlim(0, 2000)
    axes[i//2, i%2].set_xlabel(col, fontsize=12)
    axes[i//2, i%2].set_ylabel('Density', fontsize=12)
    axes[i//2, i%2].tick_params(axis='both', which='major', labelsize=10)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\Ádamo\AppData\Local\Temp\ipykernel_6964\3958789697.py:7: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(customer_df[col], shade=True, color=colors[i], ax=axes[i//2, i%2])
# C:\Users\Ádamo\AppData\Local\Temp\ipykernel_6964\3958789697.py:7: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(customer_df[col], shade=True, color=colors[i], ax=axes[i//2, i%2])
# C:\Users\Ádamo\AppData\Local\Temp\ipykernel_6964\3958789697.py:7: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(customer_df[col], shade=True, color=colors[i], ax=axes[i//2, i%2])
# ...

# %%
for each in categorical:
    plt.figure(figsize=(12,8))
    sns.countplot(x = each, data=customer_df)

# %%
# customer_id doesn't contain any useful info or carry categorical meaning

# %%
from matplotlib.colors import Normalize
from matplotlib.cm import ScalarMappable


# Create a sequential color palette
cmap = plt.get_cmap('viridis')

# Create bar plots
for each in categorical:
    plt.figure(figsize=(12, 8))
    
    # Get unique categories and their counts
    categories = customer_df[each].unique()
    num_categories = len(categories)
    
    # Generate color map and normalize colors
    norm = Normalize(vmin=0, vmax=num_categories - 1)
    color_map = ScalarMappable(cmap=cmap, norm=norm)
    
    # Plot each category with a different color
    for i, category in enumerate(categories):
        color = color_map.to_rgba(i)
        category_counts = customer_df[customer_df[each] == category].groupby(each).size().reset_index(name='count')
        plt.bar(category_counts[each], category_counts['count'], color=color, label=category)
    
    # Set labels and title
    plt.xlabel(each, fontsize=12)
    plt.ylabel('Count', fontsize=12)
    plt.title(f'Count of {each}', fontsize=14)
    plt.xticks(fontsize=10)
    plt.yticks(fontsize=10)
  
    
    plt.show()

# %%
# Define the variables
variables = ['customer_lifetime_value', 'income', 'monthly_premium_auto', 'total_claim_amount']
palette = sns.color_palette('husl', len(variables))
plt.figure(figsize=(12, 8))
for i, (var, color) in enumerate(zip(variables, palette), 1):
    plt.subplot(2, 2, i)
    sns.boxplot(y=var, data=customer_df, color=color)
    plt.xlabel(var, fontsize=12)
    plt.ylabel('Values', fontsize=12)
    plt.title(f'Boxplot of {var}', fontsize=14)
    plt.xticks(fontsize=10)
    plt.yticks(fontsize=10)

plt.tight_layout()
plt.show()

# %%
var
# Out:
# 'total_claim_amount'

# %%
numerical_df = customer_df[['customer_lifetime_value', 'income', 'monthly_premium_auto', 'months_since_last_claim', 'months_since_policy_inception', 'number_of_open_complaints', 'number_of_policies', 'total_claim_amount']]
categorical_df = customer_df[['state', 'response', 'coverage', 'education', 'effective_to_date', 'employmentstatus', 'gender', 'location_code', 'marital_status', 'policy_type', 'policy', 'renew_offer_type', 'sales_channel', 'vehicle_class', 'vehicle_size','months_since_last_claim', 'months_since_policy_inception',
       'number_of_open_complaints', 'number_of_policies']]

# %%
# Define color palette
palette = sns.color_palette('Set2')

# Customize the boxplot
for each in categorical_df:
    plt.figure(figsize=(10, 6))
    sns.boxplot(x=each, y='customer_lifetime_value', data=customer_df, palette=palette)
    plt.xlabel(each, fontsize=12)
    plt.ylabel('Customer Lifetime Value', fontsize=12)
    plt.title(f'Boxplot of Customer Lifetime Value by {each}', fontsize=14)
    plt.xticks(fontsize=10, rotation=45)  # Rotate x-axis labels for better readability
    plt.yticks(fontsize=10)
    plt.grid(axis='y', linestyle='--', alpha=0.7)  # Add grid lines for y-axis
    plt.show()

# %%
customer_df['state'].value_counts()
# Out:
# state
# California    3150
# Oregon        2601
# Arizona       1703
# Nevada         882
# Washington     798
# Name: count, dtype: int64

# %%
customer_df['response'].value_counts()
# Out:
# response
# No     7826
# Yes    1308
# Name: count, dtype: int64

# %%
customer_df['coverage'].value_counts()
# Out:
# coverage
# Basic       5568
# Extended    2742
# Premium      824
# Name: count, dtype: int64

# %%
customer_df['education'].value_counts()
# Out:
# education
# Bachelor                2748
# College                 2681
# High School or Below    2622
# Master                   741
# Doctor                   342
# Name: count, dtype: int64

# %%
customer_df['effective_to_date'].value_counts()
# Out:
# effective_to_date
# 2011-01-10    195
# 2011-01-27    194
# 2011-02-14    186
# 2011-01-26    181
# 2011-01-17    180
# 2011-01-19    179
# 2011-01-31    178
# 2011-01-03    178
# 2011-01-20    173
# 2011-02-26    169
# 2011-01-28    169
# 2011-02-19    168
# 2011-01-05    167
# 2011-02-27    167
# 2011-01-11    166
# 2011-02-04    164
# 2011-02-10    161
# 2011-02-28    161
# 2011-01-02    160
# 2011-01-21    160
# 2011-01-29    160
# 2011-02-22    158
# 2011-02-05    158
# 2011-02-03    158
# 2011-02-07    157
# 2011-02-12    156
# 2011-01-23    155
# 2011-02-01    154
# 2011-01-18    154
# 2011-01-15    153
# 2011-01-14    152
# 2011-02-11    151
# 2011-01-07    151
# 2011-01-25    151
# 2011-02-25    149
# 2011-01-08    149
# 2011-02-18    149
# 2011-02-02    149
# 2011-01-01    148
# 2011-02-21    148
# 2011-01-24    147
# 2011-01-09    146
# 2011-01-30    145
# 2011-01-13    145
# 2011-02-06    144
# 2011-01-06    143
# 2011-02-23    143
# 2011-01-16    142
# 2011-02-16    139
# ...

# %%
customer_df['employmentstatus'].value_counts()
# Out:
# employmentstatus
# Employed         5698
# Unemployed       2317
# Medical Leave     432
# Disabled          405
# Retired           282
# Name: count, dtype: int64

# %%
customer_df['gender'].value_counts()
# Out:
# gender
# F    4658
# M    4476
# Name: count, dtype: int64

# %%
customer_df['location_code'].value_counts()
# Out:
# location_code
# Suburban    5779
# Rural       1773
# Urban       1582
# Name: count, dtype: int64

# %%
customer_df['marital_status'].value_counts()
# Out:
# marital_status
# Married     5298
# Single      2467
# Divorced    1369
# Name: count, dtype: int64

# %%
customer_df['policy_type'].value_counts()
# Out:
# policy_type
# Personal Auto     6788
# Corporate Auto    1968
# Special Auto       378
# Name: count, dtype: int64

# %%
customer_df['policy'].value_counts()
# Out:
# policy
# Personal L3     3426
# Personal L2     2122
# Personal L1     1240
# Corporate L3    1014
# Corporate L2     595
# Corporate L1     359
# Special L2       164
# Special L3       148
# Special L1        66
# Name: count, dtype: int64

# %%
customer_df['renew_offer_type'].value_counts()
# Out:
# renew_offer_type
# Offer1    3752
# Offer2    2926
# Offer3    1432
# Offer4    1024
# Name: count, dtype: int64

# %%
customer_df['sales_channel'].value_counts()
# Out:
# sales_channel
# Agent          3477
# Branch         2567
# Call Center    1765
# Web            1325
# Name: count, dtype: int64

# %%
customer_df['vehicle_class'].value_counts()
# Out:
# vehicle_class
# Four-Door Car    4621
# Two-Door Car     1886
# SUV              1796
# Sports Car        484
# Luxury SUV        184
# Luxury Car        163
# Name: count, dtype: int64

# %%
customer_df['vehicle_size'].value_counts()
# Out:
# vehicle_size
# Medsize    6424
# Small      1764
# Large       946
# Name: count, dtype: int64

# %%
customer_df['months_since_last_claim'].value_counts()
# Out:
# months_since_last_claim
# 3     381
# 6     364
# 1     345
# 4     335
# 7     333
# 2     329
# 0     314
# 5     313
# 10    306
# 11    297
# 16    295
# 15    286
# 13    285
# 8     279
# 12    273
# 14    268
# 17    263
# 9     250
# 19    246
# 23    239
# 25    236
# 21    233
# 20    231
# 18    229
# 22    218
# 24    211
# 29    206
# 28    201
# 31    190
# 26    186
# 30    182
# 27    182
# 33    179
# 34    169
# 35    142
# 32    138
# Name: count, dtype: int64

# %%
customer_df['months_since_policy_inception'].value_counts()
# Out:
# months_since_policy_inception
# 59    142
# 61    128
# 50    125
# 44    115
# 3     114
#      ...
# 16     70
# 96     67
# 82     56
# 98     54
# 97     52
# Name: count, Length: 100, dtype: int64

# %%
customer_df['number_of_open_complaints'].value_counts()
# Out:
# number_of_open_complaints
# 0    7252
# 1    1011
# 2     374
# 3     292
# 4     149
# 5      56
# Name: count, dtype: int64

# %%
customer_df['number_of_policies'].value_counts()
# Out:
# number_of_policies
# 1    3251
# 2    2294
# 3    1168
# 7     433
# 9     416
# 4     409
# 5     407
# 8     384
# 6     372
# Name: count, dtype: int64

# %%
categoricals = customer_df.select_dtypes(object)
categoricals = categoricals.drop(columns='customer', axis=1)

# %%
palette = sns.color_palette('husl')
plt.figure(figsize=(16, 10))
for i, each in enumerate(categoricals, 1):
    plt.subplot(4, 4, i)
    sns.countplot(x=each, data=customer_df, palette=palette)
    plt.xlabel(each, fontsize=12)
    plt.ylabel('Count', fontsize=12)
    plt.title(f'Count of {each}', fontsize=14)
    plt.xticks(fontsize=10, rotation=45) 
    plt.yticks(fontsize=10)
    plt.grid(axis='y', linestyle='--', alpha=0.8) 
plt.tight_layout() 
plt.show()

# %%
plt.figure(figsize=(14, 8))
sns.set_style("whitegrid")
sns.countplot(x=customer_df['effective_to_date'], data=customer_df, palette='Set2')
plt.xticks(rotation=45)
plt.xlabel('Effective to Date', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.title('Count of Policies by Effective to Date', fontsize=14)

plt.show()
